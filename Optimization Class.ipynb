# %%
import gurobipy as gp 
from gurobipy import GRB
import json

# %%
data = [
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "A",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "A",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "A",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "A",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "A",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "B",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "A",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "B",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "B",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "A",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "A",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "A",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "B",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "A",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "A",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "A",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "B",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "A",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "A",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "A",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "B",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "B",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "B",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "A",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "A",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "A",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "B",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "B",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "B",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB",
            "A"
        ]
    },
    {
        "Recipient": "B",
        "Donor": [
            "AB"
        ]
    },
    {
        "Recipient": "A",
        "Donor": [
            "AB",
            "B"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "AB",
            "B",
            "A"
        ]
    },
    {
        "Recipient": "O",
        "Donor": [
            "A",
            "B"
        ]
    }
]

# Function to determine if a donor can donate to a recipient based on blood type compatibility
def is_compatible(donor_blood, recipient_blood): 
    compatibility = {
        "O": ["O", "A", "B", "AB"],
        "A": ["A", "AB"], 
        "B": ["B", "AB"], 
        "AB": ["AB"]
    }
    return recipient_blood in compatibility.get(donor_blood, [])

# Assigning IDs to each recipient and donor and creating lists
donors = []
recipients = []

for i, entry in enumerate(data):
    entry["id"] = f"R_{i+1}"  # Assign ID to each recipient
    recipients.append(entry)

    # Create donor entries and assign IDs
    for j, donor in enumerate(entry["Donor"]):
        donor_entry = {
            "id": f"D_{i+1}_{j+1}",
            "Donor": donor
        }
        donors.append(donor_entry)

# Print the recipients and donors
print("Recipients:")
for recipient in recipients:
    print(recipient)

print("\nDonors:")
for donor in donors:
    print(donor)

# Creating the compatibility matrix
d = len(donors)
r = len(recipients)

# Assuming each recipient has a 'Recipient' blood type and each donor entry has a 'Donor' blood type
C = [[1 if is_compatible(donors[i]["Donor"], recipients[j]["Recipient"]) else 0 
      for j in range(r)] for i in range(d)]

# Define the function to solve the Kidney Allocation Problem
def solve_Kidney_Allocation_Problem(donors, recipients, C):
    d = len(donors)
    r = len(recipients)

    # Create the model
    model = gp.Model("KidneyAllocation")

    # Add decision variables
    x = model.addVars(d, r, vtype=GRB.BINARY, name="x")

    # Set the objective function to maximize the number of matches
    model.setObjective(gp.quicksum(C[i][j] * x[i, j] for i in range(d) for j in range(r)), GRB.MAXIMIZE)

    # Constraints: Each donor can donate to at most one recipient
    for i in range(d):
        model.addConstr(gp.quicksum(x[i, j] for j in range(r)) <= 1, name=f"Donor_{i}")

    # Constraints: Each recipient can receive from at most one donor
    for j in range(r):
        model.addConstr(gp.quicksum(x[i, j] for i in range(d)) <= 1, name=f"Recipient_{j}")

    # Optimize the model
    model.optimize()

    # Collect matches if the solution is optimal
    matches = []
    if model.status == GRB.OPTIMAL:
        print("Optimal matches:")
        for i in range(d):
            for j in range(r):
                if x[i, j].x > 0.5:  # Check if the variable is close to 1
                    donor_id = donors[i]["id"]
                    recipient_id = recipients[j]["id"]
                    matches.append((donor_id, recipient_id))
                    print(f"Donor {donor_id} matches with Recipient {recipient_id}")

        print(f"Total number of matches: {len(matches)}")
    else:
        print("No optimal matches found.")
        print(f"Total matches: {len(matches)}")

    return matches

# Running the function
try:
    matches = solve_Kidney_Allocation_Problem(donors, recipients, C)
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Recipients:
# {'Recipient': 'B', 'Donor': ['AB'], 'id': 'R_1'}
# {'Recipient': 'O', 'Donor': ['AB', 'B', 'A'], 'id': 'R_2'}
# {'Recipient': 'A', 'Donor': ['AB', 'B'], 'id': 'R_3'}
# {'Recipient': 'B', 'Donor': ['AB'], 'id': 'R_4'}
# {'Recipient': 'O', 'Donor': ['AB', 'B', 'A'], 'id': 'R_5'}
# {'Recipient': 'B', 'Donor': ['AB'], 'id': 'R_6'}
# {'Recipient': 'A', 'Donor': ['B'], 'id': 'R_7'}
# {'Recipient': 'B', 'Donor': ['AB', 'A'], 'id': 'R_8'}
# {'Recipient': 'O', 'Donor': ['AB', 'A', 'B'], 'id': 'R_9'}
# {'Recipient': 'B', 'Donor': ['AB', 'A'], 'id': 'R_10'}
# {'Recipient': 'B', 'Donor': ['AB', 'A'], 'id': 'R_11'}
# {'Recipient': 'B', 'Donor': ['AB'], 'id': 'R_12'}
# {'Recipient': 'A', 'Donor': ['AB', 'B'], 'id': 'R_13'}
# {'Recipient': 'B', 'Donor': ['AB'], 'id': 'R_14'}
# {'Recipient': 'B', 'Donor': ['AB', 'A'], 'id': 'R_15'}
# {'Recipient': 'B', 'Donor': ['AB'], 'id': 'R_16'}
# {'Recipient': 'O', 'Donor': ['AB', 'B'], 'id': 'R_17'}
# ...
